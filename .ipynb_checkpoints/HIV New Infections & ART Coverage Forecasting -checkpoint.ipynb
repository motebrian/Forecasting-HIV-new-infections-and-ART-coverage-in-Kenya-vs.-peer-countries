# %%
# Loading the Libraries 
from prophet import Prophet
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Import and Cleaning

# %%
#Basic Data Cleaning Function
def load_cleaning (filepath):
    # Loading the data
    df = pd.read_excel(filepath,sheet_name="Estimates",header=[1],skiprows=0)
    #Keep only rows that are actual countries/regions(drop empty)
    df = df[pd.to_numeric(df['Year'], errors='coerce').notna()]
    df['Year'] = df['Year'].astype(int)
    # Filter Kenya + region + peers
    countries = ['KEN','UGA', 'TZA', 'ZAF', 'ETH']
    kenya_peers = df[df['Code'].isin(countries)].copy()
    return kenya_peers

# %%
# Loading and Cleaning data using the function.
kenya_peers = load_cleaning("C:\\Users\\MOTE\\Downloads\\Portfolio Data\\HIV Estimates Data.xlsx")
kenya_peers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175 entries, 1680 to 2134
# Data columns (total 19 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Year                                                                                          175 non-null    int64
#  1   Code                                                                                          175 non-null    object
#  2   Country_Region                                                                                175 non-null    object
#  3   Adults (15-49) prevalence (%)-Estimate                                                        175 non-null    object
#  4   Young women (15-24) prevalence (%)-Estimate                                                   175 non-null    object
# ...

# %%
# A function to clean estimates recorded in millions to numbers e.g 1.1m to 1,100,000
def clean_estimate(x):
    x = str(x).lower().replace(',', '').strip()
    x = x.replace(' ', '')  # remove spaces
    
    if 'm' in x:
        return float(x.replace('m', '')) * 1_000_000
    else:
        return pd.to_numeric(x, errors='coerce')

#Apply it to multiple columns
cols = [
    'Adults and children newly infected with HIV- Estimate',
    'Adults (15+) newly infected with HIV- Estimate',
    'Estimated adults and children living with HIV- Estimate',
    'Estimated adults (15+) living with HIV- Estimate',
    'Estimated women (15+) living with HIV- Estimate',
    'Estimated children (0-14) living with HIV- Estimate',
    'AIDS-related deaths among adults and children- Estimate',
    'AIDS-related deaths among adults (15+)- Estimate'
]

kenya_peers[cols] = kenya_peers[cols].applymap(clean_estimate)

kenya_peers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175 entries, 1680 to 2134
# Data columns (total 19 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Year                                                                                          175 non-null    int64
#  1   Code                                                                                          175 non-null    object
#  2   Country_Region                                                                                175 non-null    object
#  3   Adults (15-49) prevalence (%)-Estimate                                                        175 non-null    object
#  4   Young women (15-24) prevalence (%)-Estimate                                                   175 non-null    object
# ...

# %%
float_cols =[
    'Adults (15-49) prevalence (%)-Estimate',
    'Young women (15-24) prevalence (%)-Estimate',
    'Young men (15-24) prevalence (%)- Estimate',
    'Adults (15-49) incidence (per 1000 uninfected population) - Estimate',
    'All ages incidence (per 1000 uninfected population)- Estimate'    
]
kenya_peers[float_cols] = kenya_peers[float_cols].replace('<0.1', 0.05)
kenya_peers[float_cols] = kenya_peers[float_cols].astype(float)


whole_numbers = ['AIDS-related deaths among adults and children- Estimate',
                'AIDS-related deaths among children (0-14)- Estimate',
                'AIDS-related deaths among adults (15+)- Estimate',
                'Estimated children (0-14) living with HIV- Estimate',
                'Estimated women (15+) living with HIV- Estimate',
                'Estimated adults (15+) living with HIV- Estimate',
                'Estimated adults and children living with HIV- Estimate',
                'Pregnant women needing antiretrovirals for preventing mother-to-child transmission -Estimate',
                'Children (0-14) newly infected with HIV- Estimate',
                'Adults (15+) newly infected with HIV- Estimate',
                'Adults and children newly infected with HIV- Estimate']
kenya_peers[whole_numbers] = (
    kenya_peers[whole_numbers]
    .replace(r'[\s\xa0]', '', regex=True)
    .apply(pd.to_numeric, errors='coerce')
    .round()
    .astype('Int64')
)


kenya_peers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175 entries, 1680 to 2134
# Data columns (total 19 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Year                                                                                          175 non-null    int64
#  1   Code                                                                                          175 non-null    object
#  2   Country_Region                                                                                175 non-null    object
#  3   Adults (15-49) prevalence (%)-Estimate                                                        175 non-null    float64
#  4   Young women (15-24) prevalence (%)-Estimate                                                   175 non-null    float64
# ...

# %%
#Exporting the cleaned data for storage.
kenya_peers.to_csv(r"C:\\Users\\MOTE\\Downloads\\Portfolio Data\\cleaned_hiv_data.csv",index=False)

# %% [markdown]
# # Descrptive and Exploratory Analysis

# %%
kenya_peers.shape
# Out:
# (175, 19)

# %% [markdown]
# #### HIV INFECTION AMONG KENYA AND ITS PEERS

# %%
# Average Number of infections per year by country
kenya_peers.groupby('Code')['Adults and children newly infected with HIV- Estimate'].mean().sort_values(ascending=False)
# Out:
# Code
# ZAF    344285.714286
# TZA    104285.714286
# KEN    102542.857143
# UGA     85028.571429
# ETH     50525.714286
# Name: Adults and children newly infected with HIV- Estimate, dtype: Float64

# %%
#Average number of child infection by Country
kenya_peers.groupby('Code')['Children (0-14) newly infected with HIV- Estimate'].mean().sort_values(ascending=False)
# Out:
# Code
# ZAF    35471.428571
# KEN    28017.142857
# UGA    20805.714286
# TZA    19885.714286
# ETH    13454.285714
# Name: Children (0-14) newly infected with HIV- Estimate, dtype: Float64

# %%
# Out:
# module://matplotlib_inline.backend_inline
# n_rows: 175
# n_countries: 5
# years: 1990.0 → 2024.0
# Year                                                            float64
# Country_Region                                           string[python]
# Adults and children newly infected with HIV- Estimate           float64
# dtype: object
# Year                                                                                            0
# Code                                                                                            0
# Country_Region                                                                                  0
# Adults (15-49) prevalence (%)-Estimate                                                          0
# Young women (15-24) prevalence (%)-Estimate                                                     0
# Young men (15-24) prevalence (%)- Estimate                                                      0
# ...

# %%
# Total number of HIV infections overtime
plt.figure(figsize=(12,6))

sns.lineplot(
    data =kenya_peers,
    x='Year',
    y='Adults and children newly infected with HIV- Estimate',
    hue = 'Country_Region',
    errorbar=None
)

plt.title("Total HIV infections Overtime among Kenya and Its Peers")
plt.show()

# %% [markdown]
# #### HIV RELATED MORTALITIES AMONG KENYA AND ITS PEERS.

# %%
# Investigating HIV deaths in Kenya and its neighbors
deaths=[
    'Year',
    'Code',
    'Country_Region',
    'AIDS-related deaths among adults and children- Estimate',
    'AIDS-related deaths among children (0-14)- Estimate',
    'AIDS-related deaths among adults (15+)- Estimate',
    ]
df_deaths = kenya_peers[deaths].set_index('Year')
df_deaths = df_deaths[df_deaths['Code'].isin(['KEN','ETH','UGA','TZA','ZAF'])]
#Descriptive statistics
df_deaths.tail()
# Out:
#      Code               Country_Region  \
# Year
# 2020  TZA  United Republic of Tanzania
# 2021  TZA  United Republic of Tanzania
# 2022  TZA  United Republic of Tanzania
# 2023  TZA  United Republic of Tanzania
# 2024  TZA  United Republic of Tanzania
#
#       AIDS-related deaths among adults and children- Estimate  \
# Year
# 2020                                              33000
# 2021                                              30000
# 2022                                              29000
# 2023                                              27000
# 2024                                              26000
#
#       AIDS-related deaths among children (0-14)- Estimate  \
# Year
# 2020                                               5100
# 2021                                               4400
# 2022                                               4300
# 2023                                               3800
# 2024                                               3300
#
# ...

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=df_deaths,
    x='Year',
    y='AIDS-related deaths among adults and children- Estimate',
    hue='Code',
    marker='o',
    errorbar=None
)

plt.title('AIDS-related deaths among adults and children Over Time')

# 🔑 Save the plot
#plt.savefig("race_population_trend.png", dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# - **The Numbers rise shapely around 1996, why is that?**
# - **What happened between 2000-2005 (I approximate it was in 2003) that led to sudden drop in HIV deaths in East Africa?**

# %%
# Investigating HIV related Child Mortality before and after 2010
b4 = df_deaths[df_deaths.index<2010]
af = df_deaths[df_deaths.index>=2010]

print("The shape of b4 is",  b4.shape)
print("The shape of af is",  af.shape)
# Out:
# The shape of b4 is (100, 5)
# The shape of af is (75, 5)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

sns.boxplot(data=b4, x='Country_Region',
            y='AIDS-related deaths among adults and children- Estimate',
            ax=axes[0])
axes[0].set_title("Before 2010")


sns.boxplot(data=af, x='Country_Region',
            y='AIDS-related deaths among adults and children- Estimate',
            ax=axes[1])
axes[1].set_title("After 2010")

fig.suptitle("AVG AIDS-related deaths among Adults and children between Kenya and its Peers")
for ax in axes:
    ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=df_deaths,
    x='Year',
    y='AIDS-related deaths among children (0-14)- Estimate',
    hue='Country_Region',
    marker='o',
    errorbar=None
)

plt.title('AIDS-related deaths among children (0-14) Overtime')

# 🔑 Save the plot
#plt.savefig("race_population_trend.png", dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# **Has South Africa managed to reduce HIV related child mortality  below its neighbors? What happened around in 2010 that led to that drop?**

# %%
sns.boxplot(data=b4,x='Country_Region',y='AIDS-related deaths among children (0-14)- Estimate')
plt.title("Avg AIDS related deaths across East Africa before 2010")
plt.xticks(rotation=45);

# %%
sns.boxplot(data=af,x='Country_Region',y='AIDS-related deaths among children (0-14)- Estimate')
plt.title("Avg AIDS related deaths across East Africa after 2010")
plt.xticks(rotation=45);

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

sns.boxplot(data=b4, x='Country_Region',
            y='AIDS-related deaths among children (0-14)- Estimate',
            ax=axes[0])
axes[0].set_title("Before 2010")


sns.boxplot(data=af, x='Country_Region',
            y='AIDS-related deaths among children (0-14)- Estimate',
            ax=axes[1])
axes[1].set_title("After 2010")

fig.suptitle("AIDS-related deaths among children (0-14) across East Africa")
for ax in axes:
    ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **What is Kenya doing right that Tz can learn from?**
# - **Generally what are the lessons from SA on reducing AIDS related child mortality?**
